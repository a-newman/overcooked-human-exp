# %%
import json
import pandas as pd
import pprint
import numpy as np

# %%
# Opening JSON file
f = open('../experiment_data/mturk-experiment-2.json',)
  
data = json.load(f)

f.close()

# %% [markdown]
# Data is a list of dictionaries, where each dictionary corresponds to one MTurk assignment.

# %%
pd.DataFrame.from_dict(data)
# Out:
#                             HITId                    AssignmentId  \
# 0  34F34TZU858LL1ONLL19TG3LV5SJ2W  35BLDD71IG6N5RONHJT77ZK9B9QVZN
# 1  34F34TZU858LL1ONLL19TG3LV5SJ2W  3WZ36BJEVDPCA1HI6ADPKZPLNLPBTI
# 2  34F34TZU858LL1ONLL19TG3LV5SJ2W  3SEPORI8WX83D3LP6O2BBC6WQZWZAX
# 3  34F34TZU858LL1ONLL19TG3LV5SJ2W  3LRKMWOKBFQE80QLT99W5UNYEBXZ2J
# 4  34F34TZU858LL1ONLL19TG3LV5SJ2W  3VNL7UK1XPS2NITYBCZL3PG62KTTFW
# 5  34F34TZU858LL1ONLL19TG3LV5SJ2W  345LHZDED71M7JSURMOT7CDBI7J3UA
# 6  34F34TZU858LL1ONLL19TG3LV5SJ2W  3KYQYYSHY5GPC6AUOPIWLF7YRZLODJ
# 7  34F34TZU858LL1ONLL19TG3LV5SJ2W  3SLE99ER0XM8WDQHC2276NQ28KVZBC
# 8  34F34TZU858LL1ONLL19TG3LV5SJ2W  3TY7ZAOG5PTCNVOLEL28ZR66D8P0KB
#
#          WorkerId        workerId  \
# 0  A14YPOV9J2FAYU  A14YPOV9J2FAYU
# 1  A10HW8JXM17XLD  A10HW8JXM17XLD
# 2  A1969Q0R4Y0E3J  A1969Q0R4Y0E3J
# 3  A2D8XOCFB0J0BO  A2D8XOCFB0J0BO
# 4  A2V8CV9H3U2M5P  A2V8CV9H3U2M5P
# 5  A36BETX5G9BSZ2  A36BETX5G9BSZ2
# 6   A3ROADR7T6811   A3ROADR7T6811
# 7  A24M9OW53CLT94  A24M9OW53CLT94
# 8  A2547CTY15P0SM  A2547CTY15P0SM
#
#                                              results
# 0  {'data': [{}, {'age': '4554', 'gender': 'Man'}...
# 1  {'data': [{}, {'age': '3544', 'gender': 'Woman...
# 2  {'data': [{}, {'age': '2534', 'gender': 'Woman...
# 3  {'data': [{}, {'age': '3544', 'gender': 'Man'}...
# 4  {'data': [{}, {'age': '5564', 'gender': 'Woman...
# 5  {'data': [{}, {'age': '1824', 'gender': 'Man'}...
# 6  {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 7  {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 8  {'data': [{}, {'age': '3544', 'gender': 'Woman...

# %%
output = pd.DataFrame()

for assignment in data:
    output = output.append(assignment['results']['data'][-2], ignore_index=True)


feedback_1 = 'How good was your partner at playing the game?'
feedback_2 = 'Did you have any issues with the task or the interface?'
feedback_3 = 'Was the game too short, too long, or a good length?'

pd.set_option('display.max_colwidth', None)
output
# Out:
#                                                                   feedbackAdditional  \
# 0
# 1  This was a very interesting study. Thank you for the opportunity to participate.
# 2
# 3                                                            Co-Operation to Partner
# 4                                                                          good task
# 5                                                                               GOOD
# 6                                                                               none
# 7                                                                               None
# 8                                                                   very interesting
#
#                                                                     feedbackBugs  \
# 0
# 1                                             I did not encounter any problems.
# 2  I HAD TO COMPLETE THIS TASK TWICE BECAUSE IT FAILED TO SUBMIT THE FIRST TIME!
# 3                                                                             No
# 4                                                                             No
# 5                                                                             NO
# 6                                                                           none
# 7                                                                           None
# 8                                                                             no
#
#                                                    feedbackLength
# 0
# 1                            I think the length was appropriate.
# 2
# 3                                                          longer
# 4                                          like the length played
# 5                                                          LONGER
# 6                                                          longer
# 7  I felt the length was enough to determine my partner's skills.
# 8                                                very interesting
