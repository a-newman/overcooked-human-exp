# %%
import json
import pandas as pd
import pprint
import numpy as np

# %%
# Opening JSON file
f = open('/home/dy/filerepo/Research/multiagent-human-experiment/mturk/experiment_data/mturk-experiment-4-20210826.json',)
  
data = json.load(f)

f.close()

# %% [markdown]
# Data is a list of dictionaries, where each dictionary corresponds to one MTurk assignment.

# %%
pd.DataFrame.from_dict(data)
# Out:
#                              HITId                    AssignmentId  \
# 0   3IKMEYR0M54GWLU5361LUV3YAZGK2U  3907X2AHFAEKUWOF60BUEWLK59G2PM
# 1   3IKMEYR0M54GWLU5361LUV3YAZGK2U  3EQHHY4HQ216GGE3L0N5IUA4OSL5GN
# 2   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  30MVJZJNHWMZ856GWWLPRN7M2GFJ9Q
# 3   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  3K2755HG52CV6TX1PMZ6YLYK0UDDFY
# 4   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  3GLB5JMZF741KTTW065OG6YW19DDGX
# 5   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  3NPFYT4IZMDFIZYDR660AD1OHRPGX2
# 6   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  3WQ3B2KGEIPB1H594RTFET6QWZI1BE
# 7   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  34FNN24DCWI627Z3F69BPUH8TO4Y57
# 8   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  39GXDJN2O3N8LVN08TTUUFN5DX48VB
# 9   36JW4WBR1FT9VP59LGDV1MHVRMHFH5  3GFK2QRXXJQ2D24305RN4XWSIG4W56
# 10  36JW4WBR1FT9VP59LGDV1MHVRMHFH5  3GFK2QRXXJQ2D24305RN4XWSIGF5WQ
# 11  391JB9X407H63PYYDOK594HWG4XMKN  3483FV8BEOSCKQ6AR4CL8WU3A4L62F
# 12  391JB9X407H63PYYDOK594HWG4XMKN  3SEPORI8WX83D3LP6O2BBC6WRWAAZH
# 13  391JB9X407H63PYYDOK594HWG4XMKN  37U1UTWH95VGSO6JZ9OKTIY2SRR8RI
# 14  391JB9X407H63PYYDOK594HWG4XMKN  3QRYMNZ7F8QEBA6F90IYBUPF57MTN3
# 15  391JB9X407H63PYYDOK594HWG4XMKN  388U7OUMFHAYAZ1G45B503SK9TER0D
# 16  391JB9X407H63PYYDOK594HWG4XMKN  3PQ8K71NH7T2CVDHUWMCUJFNIB9AAM
# 17  391JB9X407H63PYYDOK594HWG4XMKN  3PPTZCWAL0TV0JS6VKZX1CL1VEAQZI
# 18  391JB9X407H63PYYDOK594HWG4XMKN  3DHE4R9OC6KEHJVG3HL7KN7S4IW2GL
# 19  391JB9X407H63PYYDOK594HWG4XMKN  3Z7ISHFUHA4PUFSA9QIXFL0118SZ8K
#
#           WorkerId        workerId  \
# 0   A1JWF4WXGEXQKU  A1JWF4WXGEXQKU
# 1    AGSSG1SWNWGHD   AGSSG1SWNWGHD
# 2   A13WTEQ06V3B6D  A13WTEQ06V3B6D
# 3   A22HIX1M4QXZBB  A22HIX1M4QXZBB
# 4   A1A4W5I56BSH44  A1A4W5I56BSH44
# 5   A2HJZ7G4Z9BXVS  A2HJZ7G4Z9BXVS
# 6    A46PRT7P1Q26J   A46PRT7P1Q26J
# 7   A1F4GAT1TNORPP  A1F4GAT1TNORPP
# 8    AKP66RIZ3LQVX   AKP66RIZ3LQVX
# 9   A1JZMXDCPZVZAU  A1JZMXDCPZVZAU
# 10  A247Y7QBVKMZ4C  A247Y7QBVKMZ4C
# 11  A1PF01FF85HUY4  A1PF01FF85HUY4
# 12  A1ODA3Q5H6HTDQ  A1ODA3Q5H6HTDQ
# 13  A1EKWGMWSV9GQE  A1EKWGMWSV9GQE
# 14  A3BOOIQQX6HXM2  A3BOOIQQX6HXM2
# 15  A1BISRD579W10W  A1BISRD579W10W
# 16  A1YFFRRABDKJU5  A1YFFRRABDKJU5
# 17  A26GR4X783R1O9  A26GR4X783R1O9
# 18  A2AKJ3UD69QC5K  A2AKJ3UD69QC5K
# 19  A2SR85I8JMO1ZZ  A2SR85I8JMO1ZZ
#
#                                               results
# 0   {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 1   {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 2   {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 3   {'data': [{}, {'age': '2534', 'gender': 'Woman...
# 4   {'data': [{}, {'age': '4554', 'gender': 'Woman...
# 5   {'data': [{}, {'age': '2534', 'gender': 'Woman...
# 6   {'data': [{}, {'age': '5564', 'gender': 'Woman...
# 7   {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 8   {'data': [{}, {'age': '1824', 'gender': 'Man'}...
# 9   {'data': [{}, {'age': '3544', 'gender': 'Woman...
# 10  {'data': [{}, {'age': '2534', 'gender': 'Woman...
# 11  {'data': [{}, {'age': '3544', 'gender': 'Man'}...
# 12  {'data': [{}, {'age': '2534', 'gender': 'Woman...
# 13  {'data': [{}, {'age': '3544', 'gender': 'Woman...
# 14  {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 15  {'data': [{}, {'age': '3544', 'gender': 'Man'}...
# 16  {'data': [{}, {'age': '3544', 'gender': 'Man'}...
# 17  {'data': [{}, {'age': '2534', 'gender': 'Woman...
# 18  {'data': [{}, {'age': '2534', 'gender': 'Man'}...
# 19  {'data': [{}, {'age': '2534', 'gender': 'Woman...

# %%
output = pd.DataFrame()

for assignment in data:
    output = output.append(assignment['results']['data'][-2], ignore_index=True)


feedback_1 = 'How good was your partner at playing the game?'
feedback_2 = 'Did you have any issues with the task or the interface?'
feedback_3 = 'Was the game too short, too long, or a good length?'

pd.set_option('display.max_colwidth', None)
output
# Out:
#                                         feedbackAdditional  \
# 0                                                  Nothing
# 1
# 2   I had a enjoyable time playing and working on the HIT.
# 3
# 4
# 5                                                     none
# 6                                                       no
# 7                                                     None
# 8
# 9
# 10                                                    NICE
# 11                                                      no
# 12                                                     N/A
# 13                                very interesting survey.
# 14
# 15                                                    Good
# 16                                                    Nice
# 17                                             interesting
# 18
# 19                                 None at all, thank you!
#
#                                      feedbackBugs  \
# 0                                         Nothing
# 1                                            None
# 2   I did not encounter any issues with the task.
# 3
# 4
# 5                                            none
# 6                              Yes. Slow working.
# 7                                              No
# 8
# 9
# 10                                             NO
# 11                                            no
# 12                                     No issues.
# 13                                      no issues
# 14
# 15                                           Good
# 16                                             No
# 17                                           none
# 18
# 19                                   No bugs here
#
#                                                                                                            feedbackLength
# 0                                                                                                                 Shorter
# 1                                                                                                          It was alright
# 2   I enjoyed the length of the overcooked game, I found it was the right length to get a good feeling of the AI partner.
# 3
# 4
# 5                                                                                                          i like longer
# 6                                                                       60 seconds. I would prefer the game to be longer.
# 7                                                                                                    I liked the length,
# 8                                                      I like the length, personally. It didn't seem to short or to long.
# 9
# 10
# 11                                                                                                             too ,long
# 12                                              The minute length was good - short but enough time to get a few cooks in.
# 13                                                                                             shorter. i like the length
# 14
# 15                                                                                                                   Good
# 16                                                                                                         Shorter length
# 17
# 18
# 19                                                    It felt so short! I would have been glad to keep playing with them.
