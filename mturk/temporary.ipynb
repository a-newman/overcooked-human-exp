# %%
import json

# %%
# Opening JSON file
f = open('/home/dy/filerepo/Research/multiagent-human-experiment/mturk/assignments-prod-2.json')
  
data = json.load(f)

f.close()

# %%
data[0]['results']['data'][-1]
# Out:
# {'games': [['human', 'sac_self_play_coordination_ring_0'],
#   ['human', 'nct_coordination_ring'],
#   ['human', 'action_cml_v_sac_none_no_ib'],
#   ['human', 'sac_v_bc_states_coordination_ring_0']],
#  'nGamesPerPartner': 1,
#  'nSecondsPerGame': 60,
#  'nSecondsPerTutorial': 0,
#  'nSoupsPassTutorial': 5,
#  'layout': 'coordination_ring',
#  'path': 'coordination_ring.json',
#  'gameOrder': [['human', 'sac_self_play_coordination_ring_0'],
#   ['human', 'nct_coordination_ring'],
#   ['human', 'sac_v_bc_states_coordination_ring_0'],
#   ['human', 'action_cml_v_sac_none_no_ib']]}

# %%
game_id = data[0]['results']['data'][8]['trial_id']

f = open('../server/data/server/' + game_id + '.json')
trial_data = json.load(f)  
f.close()

# %%
trial_data
# Out:
# {'trial_id': '1629947861.6321177',
#  'trajectory': [{'state': {'players': [{'position': [2, 1],
#       'orientation': [0, -1],
#       'held_object': None},
#      {'position': [1, 2], 'orientation': [0, -1], 'held_object': None}],
#     'objects': [],
#     'order_list': []},
#    'joint_action': [[0, 0], [0, 1]],
#    'reward': 0,
#    'time_left': 59.99711632728577,
#    'score': 0,
#    'time_elapsed': 0.0028853416442871094,
#    'cur_gameloop': 1,
#    'layout': [['X', 'X', 'X', 'P', 'X'],
#     ['X', ' ', ' ', ' ', 'P'],
#     ['D', ' ', 'X', ' ', 'X'],
#     ['O', ' ', ' ', ' ', 'X'],
#     ['X', 'O', 'S', 'X', 'X']],
#    'layout_name': 'coordination_ring',
#    'trial_id': '1629947861.6321177',
#    'player_0_id': '3bada6696e8045fdbcdd8544bb1e8bab',
#    'player_1_id': 'sac_v_bc_states_coordination_ring_0_1',
#    'player_0_is_human': True,
#    'player_1_is_human': False,
#    'info': {'curr_game_reward': 0}},
#   {'state': {'players': [{'position': [2, 1],
# ...
